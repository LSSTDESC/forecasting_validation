# %%
import pyccl as ccl
print(f"I am using pyccl version {ccl.__version__}")
import numpy as np
from scripts.presets import Presets
import scripts.testing_chi as p
from scripts.testing_chi import ChiRedshift
# Out:
# I am using pyccl version 3.0.2

# %%
redshift_max = 3.0
forecast_year = "1"

presets = Presets(redshift_max=redshift_max,
                  forecast_year=forecast_year)
cr = ChiRedshift(presets)

# %%
chi = cr.chi_redshift_resolution()

# %%
p.plot_compare_chi(chi)
